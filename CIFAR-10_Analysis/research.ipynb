# %%
import keras 
from keras.models import Sequential
from keras.layers import  Conv2D, MaxPooling2D, Dense, Flatten,Dropout,Activation
from keras.layers import BatchNormalization
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt 
import numpy as np
from keras import regularizers
from keras.datasets import cifar10
from keras.optimizers import SGD 

(x_train,y_train),(x_test,y_test) = cifar10.load_data()

print('Shape of training dataset :',x_train.shape)
print('Shape of testing dataste :' ,x_test.shape)

#formatting the dataset 
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

x_train = x_train/255.
x_test = x_test/255.

y_train = np_utils.to_categorical(y_train,10)
y_test = np_utils.to_categorical(y_test,10)
# Out:
# Shape of training dataset : (50000, 32, 32, 3)
# Shape of testing dataste : (10000, 32, 32, 3)

# %%
model = Sequential()

model.add(Conv2D(32,(3,3),input_shape=[32,32,3],kernel_regularizer=regularizers.l2(0.0003),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv2D(32,(3,3),kernel_regularizer=regularizers.l2(0.0003),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(64,(3,3),kernel_regularizer=regularizers.l2(0.0003),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv2D(64,(3,3),kernel_regularizer=regularizers.l2(0.0003),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(128,(3,3),kernel_regularizer=regularizers.l2(0.0003),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv2D(128,(3,3),kernel_regularizer=regularizers.l2(0.0003),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(256,(3,3),kernel_regularizer=regularizers.l2(0.0003),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv2D(256,(3,3),kernel_regularizer=regularizers.l2(0.0003),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(512,(3,3),kernel_regularizer=regularizers.l2(0.0003),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv2D(512,(3,3),kernel_regularizer=regularizers.l2(0.0003),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
#model.add(MaxPooling2D(2,2))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(512))
model.add(Dropout(0.2))
model.add(Dense(10,activation='softmax'))

model.summary()

#SGD = SGD(lr=0.01, decay=1e-6, momentum=0.9)

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
datagen = ImageDataGenerator(
    featurewise_center=False,
    featurewise_std_normalization=False,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip = False)

# compute quantities required for featurewise normalization
# (std, mean, and principal components if ZCA whitening is applied)
datagen.fit(x_train)

# fits the model on batches with real-time data augmentation:
history = model.fit_generator(datagen.flow(x_train, y_train, batch_size=32),
                    steps_per_epoch=len(x_train) / 32, epochs=50,
                    validation_data = (x_test,y_test))


plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_198 (Conv2D)          (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_193 (Bat (None, 32, 32, 32)        128
# _________________________________________________________________
# activation_193 (Activation)  (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout_121 (Dropout)        (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_199 (Conv2D)          (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_194 (Bat (None, 32, 32, 32)        128
# _________________________________________________________________
# activation_194 (Activation)  (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d_76 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_200 (Conv2D)          (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_195 (Bat (None, 16, 16, 64)        256
# _________________________________________________________________
# activation_195 (Activation)  (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_122 (Dropout)        (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_201 (Conv2D)          (None, 16, 16, 64)        36928
# _________________________________________________________________
# batch_normalization_196 (Bat (None, 16, 16, 64)        256
# _________________________________________________________________
# activation_196 (Activation)  (None, 16, 16, 64)        0
# _________________________________________________________________
# max_pooling2d_77 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_202 (Conv2D)          (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_197 (Bat (None, 8, 8, 128)         512
# _________________________________________________________________
# activation_197 (Activation)  (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_123 (Dropout)        (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_203 (Conv2D)          (None, 8, 8, 128)         147584
# _________________________________________________________________
# batch_normalization_198 (Bat (None, 8, 8, 128)         512
# _________________________________________________________________
# activation_198 (Activation)  (None, 8, 8, 128)         0
# _________________________________________________________________
# max_pooling2d_78 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_204 (Conv2D)          (None, 4, 4, 256)         295168
# _________________________________________________________________
# batch_normalization_199 (Bat (None, 4, 4, 256)         1024
# _________________________________________________________________
# activation_199 (Activation)  (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_124 (Dropout)        (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_205 (Conv2D)          (None, 4, 4, 256)         590080
# _________________________________________________________________
# batch_normalization_200 (Bat (None, 4, 4, 256)         1024
# _________________________________________________________________
# activation_200 (Activation)  (None, 4, 4, 256)         0
# _________________________________________________________________
# max_pooling2d_79 (MaxPooling (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_206 (Conv2D)          (None, 2, 2, 512)         1180160
# _________________________________________________________________
# batch_normalization_201 (Bat (None, 2, 2, 512)         2048
# _________________________________________________________________
# activation_201 (Activation)  (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_125 (Dropout)        (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_207 (Conv2D)          (None, 2, 2, 512)         2359808
# _________________________________________________________________
# batch_normalization_202 (Bat (None, 2, 2, 512)         2048
# _________________________________________________________________
# activation_202 (Activation)  (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_126 (Dropout)        (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_16 (Flatten)         (None, 2048)              0
# _________________________________________________________________
# dense_30 (Dense)             (None, 512)               1049088
# _________________________________________________________________
# dropout_127 (Dropout)        (None, 512)               0
# _________________________________________________________________
# dense_31 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 5,774,378
# Trainable params: 5,770,410
# Non-trainable params: 3,968
# _________________________________________________________________
# Epoch 1/50
# 1563/1562 [==============================] - 138s 88ms/step - loss: 3.7417 - acc: 0.1367 - val_loss: 2.6309 - val_acc: 0.1797
# Epoch 2/50
# 1563/1562 [==============================] - 114s 73ms/step - loss: 3.0829 - acc: 0.1803 - val_loss: 2.3013 - val_acc: 0.2143
# Epoch 3/50
# 1563/1562 [==============================] - 115s 74ms/step - loss: 2.2109 - acc: 0.2411 - val_loss: 2.0480 - val_acc: 0.3050
# Epoch 4/50
# 1563/1562 [==============================] - 115s 74ms/step - loss: 2.0089 - acc: 0.3164 - val_loss: 1.7748 - val_acc: 0.4118
# Epoch 5/50
# 1563/1562 [==============================] - 115s 74ms/step - loss: 1.8301 - acc: 0.3940 - val_loss: 1.7344 - val_acc: 0.4479
# Epoch 6/50
# 1563/1562 [==============================] - 118s 75ms/step - loss: 1.6695 - acc: 0.4715 - val_loss: 1.9080 - val_acc: 0.4773
# Epoch 7/50
# 1563/1562 [==============================] - 114s 73ms/step - loss: 1.5418 - acc: 0.5292 - val_loss: 1.3827 - val_acc: 0.5880
# Epoch 8/50
# 1563/1562 [==============================] - 158s 101ms/step - loss: 1.4258 - acc: 0.5784 - val_loss: 1.3728 - val_acc: 0.5988
# Epoch 9/50
# 1563/1562 [==============================] - 205s 131ms/step - loss: 1.3483 - acc: 0.6106 - val_loss: 1.1817 - val_acc: 0.6610
# Epoch 10/50
# 1563/1562 [==============================] - 184s 118ms/step - loss: 1.2967 - acc: 0.6376 - val_loss: 1.1171 - val_acc: 0.6938
# Epoch 11/50
# 1563/1562 [==============================] - 113s 72ms/step - loss: 1.2551 - acc: 0.6570 - val_loss: 1.2244 - val_acc: 0.6785
# Epoch 12/50
# 1563/1562 [==============================] - 116s 74ms/step - loss: 1.2286 - acc: 0.6696 - val_loss: 1.0131 - val_acc: 0.7458
# Epoch 13/50
# 1563/1562 [==============================] - 115s 74ms/step - loss: 1.1974 - acc: 0.6851 - val_loss: 1.1457 - val_acc: 0.6963
# Epoch 14/50
# 1563/1562 [==============================] - 111s 71ms/step - loss: 1.1839 - acc: 0.6924 - val_loss: 1.1863 - val_acc: 0.6940
# Epoch 15/50
# 1563/1562 [==============================] - 120s 77ms/step - loss: 1.1616 - acc: 0.7035 - val_loss: 1.1136 - val_acc: 0.7266
# Epoch 16/50
# 1563/1562 [==============================] - 116s 74ms/step - loss: 1.1537 - acc: 0.7069 - val_loss: 1.1074 - val_acc: 0.7171
# Epoch 17/50
# 1563/1562 [==============================] - 116s 74ms/step - loss: 1.1479 - acc: 0.7108 - val_loss: 1.0254 - val_acc: 0.7526
# Epoch 18/50
# 1563/1562 [==============================] - 117s 75ms/step - loss: 1.1344 - acc: 0.7189 - val_loss: 1.1598 - val_acc: 0.7103
# Epoch 19/50
# 1563/1562 [==============================] - 115s 74ms/step - loss: 1.1229 - acc: 0.7232 - val_loss: 1.0053 - val_acc: 0.7552
# Epoch 20/50
# 1563/1562 [==============================] - 115s 74ms/step - loss: 1.1177 - acc: 0.7240 - val_loss: 0.9889 - val_acc: 0.7635
# Epoch 21/50
# 1563/1562 [==============================] - 115s 74ms/step - loss: 1.1123 - acc: 0.7257 - val_loss: 1.0213 - val_acc: 0.7444
# Epoch 22/50
# 1563/1562 [==============================] - 115s 73ms/step - loss: 1.1031 - acc: 0.7318 - val_loss: 1.1272 - val_acc: 0.7286
# Epoch 23/50
# 1563/1562 [==============================] - 116s 74ms/step - loss: 1.1059 - acc: 0.7328 - val_loss: 1.0098 - val_acc: 0.7622
# Epoch 24/50
# 1563/1562 [==============================] - 116s 74ms/step - loss: 1.0979 - acc: 0.7347 - val_loss: 1.1694 - val_acc: 0.7194
# Epoch 25/50
# 1563/1562 [==============================] - 115s 74ms/step - loss: 1.0918 - acc: 0.7379 - val_loss: 1.1783 - val_acc: 0.6994
# Epoch 26/50
# 1563/1562 [==============================] - 114s 73ms/step - loss: 1.0845 - acc: 0.7401 - val_loss: 1.0160 - val_acc: 0.7547
# Epoch 27/50
# 1563/1562 [==============================] - 114s 73ms/step - loss: 1.0799 - acc: 0.7460 - val_loss: 0.9671 - val_acc: 0.7805
# Epoch 28/50
# 1563/1562 [==============================] - 115s 74ms/step - loss: 1.0808 - acc: 0.7444 - val_loss: 0.9636 - val_acc: 0.7758
# Epoch 29/50
# 1563/1562 [==============================] - 116s 74ms/step - loss: 1.0725 - acc: 0.7473 - val_loss: 1.0538 - val_acc: 0.7453
# Epoch 30/50
# 1563/1562 [==============================] - 114s 73ms/step - loss: 1.0663 - acc: 0.7473 - val_loss: 1.0183 - val_acc: 0.7638
# Epoch 31/50
# 1563/1562 [==============================] - 116s 74ms/step - loss: 1.0627 - acc: 0.7493 - val_loss: 1.0525 - val_acc: 0.7518
# Epoch 32/50
# 1563/1562 [==============================] - 116s 74ms/step - loss: 1.0643 - acc: 0.7505 - val_loss: 0.9625 - val_acc: 0.7758
# Epoch 33/50
# 1563/1562 [==============================] - 114s 73ms/step - loss: 1.0616 - acc: 0.7527 - val_loss: 0.9315 - val_acc: 0.7917
# Epoch 34/50
# 1563/1562 [==============================] - 117s 75ms/step - loss: 1.0599 - acc: 0.7535 - val_loss: 0.9691 - val_acc: 0.7815
# Epoch 35/50
# 1563/1562 [==============================] - 116s 74ms/step - loss: 1.0532 - acc: 0.7573 - val_loss: 0.8761 - val_acc: 0.8059
# Epoch 36/50
# 1563/1562 [==============================] - 117s 75ms/step - loss: 1.0481 - acc: 0.7567 - val_loss: 0.9648 - val_acc: 0.7820
# Epoch 37/50
# 1563/1562 [==============================] - 115s 73ms/step - loss: 1.0577 - acc: 0.7569 - val_loss: 1.0007 - val_acc: 0.7771
# Epoch 38/50
# 1563/1562 [==============================] - 114s 73ms/step - loss: 1.0500 - acc: 0.7576 - val_loss: 1.0613 - val_acc: 0.7512
# Epoch 39/50
# 1563/1562 [==============================] - 116s 74ms/step - loss: 1.0440 - acc: 0.7600 - val_loss: 1.0149 - val_acc: 0.7560
# Epoch 40/50
# 1563/1562 [==============================] - 115s 74ms/step - loss: 1.0383 - acc: 0.7602 - val_loss: 0.9972 - val_acc: 0.7664
# Epoch 41/50
# 1563/1562 [==============================] - 114s 73ms/step - loss: 1.0465 - acc: 0.7585 - val_loss: 1.0319 - val_acc: 0.7628
# Epoch 42/50
# 1563/1562 [==============================] - 115s 73ms/step - loss: 1.0347 - acc: 0.7626 - val_loss: 0.9803 - val_acc: 0.7813
# Epoch 43/50
# 1563/1562 [==============================] - 116s 74ms/step - loss: 1.0416 - acc: 0.7605 - val_loss: 0.8627 - val_acc: 0.8117
# Epoch 44/50
# 1563/1562 [==============================] - 116s 74ms/step - loss: 1.0367 - acc: 0.7620 - val_loss: 0.9440 - val_acc: 0.7922
# Epoch 45/50
# 1563/1562 [==============================] - 118s 76ms/step - loss: 1.0315 - acc: 0.7660 - val_loss: 0.9075 - val_acc: 0.8064
# Epoch 46/50
# 1563/1562 [==============================] - 116s 74ms/step - loss: 1.0287 - acc: 0.7664 - val_loss: 1.2065 - val_acc: 0.7114
# Epoch 47/50
# 1563/1562 [==============================] - 118s 76ms/step - loss: 1.0316 - acc: 0.7643 - val_loss: 0.9994 - val_acc: 0.7729
# Epoch 48/50
# 1563/1562 [==============================] - 117s 75ms/step - loss: 1.0255 - acc: 0.7661 - val_loss: 0.9677 - val_acc: 0.7826
# Epoch 49/50
# 1563/1562 [==============================] - 116s 74ms/step - loss: 1.0276 - acc: 0.7641 - val_loss: 0.9730 - val_acc: 0.7872
# Epoch 50/50
# 1563/1562 [==============================] - 118s 75ms/step - loss: 1.0237 - acc: 0.7658 - val_loss: 1.0600 - val_acc: 0.7553
